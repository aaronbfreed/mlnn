# %%
print("Hello World")
# Out:
# Hello World

# %%
import math
a = 1
b = 2
c = a^2 + b^2
print(math.sqrt(c))
# Out:
# 2.6457513110645907

# %%
import matplotlib.pyplot as plt
do = (1,2,3)
ra = (2,4,9)
plt.plot(do,ra)
plt.show()
